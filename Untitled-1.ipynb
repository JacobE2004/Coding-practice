# %%
import numpy as np

# %%
from astropy.io import fits
from astropy.table import Table
from astropy.coordinates import SkyCoord
import numpy as np
import os

def get_ra_dec_mag(C:\Users\Jmell\Desktop\NGC 6819\Light\I'\combinede):
    """
    Extract RA, Dec, and magnitude from a FITS file header.
    """
    hdul = fits.open(r"C:\Users\Jmell\Desktop\NGC 6819\Light\I'\combined")
    header = hdul[0].header
    
    # Extract RA, Dec, and Magnitude (assuming they are stored in the header)
    ra = header['RA']
    dec = header['DEC']
    mag = header['MAG']

    hdul.close()

    return ra, dec, mag

def organize_fits_by_ra_dec_mag(directory):
    """
    Organize FITS files in a directory by their RA, Dec, and Magnitude.
    """
    fits_files = [file for file in os.listdir(directory) if file.endswith('.fits')]

    grouped_files = {}

    for fits_file in fits_files:
        ra, dec, mag = get_ra_dec_mag(os.path.join(directory, fits_file))
        key = (ra, dec, mag)
        if key not in grouped_files:
            grouped_files[key] = []
        grouped_files[key].append(fits_file)

    return grouped_files

def main():
    directory = '/path/to/fits/files'
    grouped_files = organize_fits_by_ra_dec_mag(directory)

    # Output organized files
    for key, files in grouped_files.items():
        ra, dec, mag = key
        output_directory = os.path.join(directory, f'RA{ra}_Dec{dec}_Mag{mag}')
        os.makedirs(output_directory, exist_ok=True)
        for fits_file in files:
            os.rename(os.path.join(directory, fits_file), os.path.join(output_directory, fits_file))

if __name__ == "__main__":
    main()
# Out:
#   Cell In[2], line 7
#     def get_ra_dec_mag(C:\Users\Jmell\Desktop\NGC 6819\Light\I'\combinede):
#                           ^
# SyntaxError: unexpected character after line continuation character

# %%
from astropy.io import fits
import os

def get_ra_dec_mag(fits_file):
    """
    Extract RA, Dec, and magnitude from a FITS file header.
    """
    hdul = fits.open(fits_file)
    header = hdul[0].header
    
    # Extract RA, Dec, and Magnitude (assuming they are stored in the header)
    ra = header['RA']
    dec = header['DEC']
    mag = header['MAG']

    hdul.close()

    return ra, dec, mag

def organize_fits_by_ra_dec_mag(directory):
    """
    Organize FITS files in a directory by their RA, Dec, and Magnitude.
    """
    fits_files = [file for file in os.listdir(directory) if file.endswith('.fits')]

    grouped_files = {}

    for fits_file in fits_files:
        ra, dec, mag = get_ra_dec_mag(os.path.join(directory, fits_file))
        key = (ra, dec, mag)
        if key not in grouped_files:
            grouped_files[key] = []
        grouped_files[key].append(fits_file)

    return grouped_files

def main():
    directory = r'C:\Users\Jmell\Desktop\NGC 6819\Light\I\combined'
    grouped_files = organize_fits_by_ra_dec_mag(directory)

    # Output organized files
    for key, files in grouped_files.items():
        ra, dec, mag = key
        output_directory = os.path.join(directory, f'RA{ra}_Dec{dec}_Mag{mag}')
        os.makedirs(output_directory, exist_ok=True)
        for fits_file in files:
            os.rename(os.path.join(directory, fits_file), os.path.join(output_directory, fits_file))

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 50
#      47             os.rename(os.path.join(directory, fits_file), os.path.join(output_directory, fits_file))
#      49 if __name__ == "__main__":
# ---> 50     main()
#
# Cell In[6], line 39, in main()
#      37 def main():
#      38     directory = r'C:\Users\Jmell\Desktop\NGC 6819\Light\I\combined'
# ---> 39     grouped_files = organize_fits_by_ra_dec_mag(directory)
#      41     # Output organized files
#      42     for key, files in grouped_files.items():
#
# Cell In[6], line 24, in organize_fits_by_ra_dec_mag(directory)
#      20 def organize_fits_by_ra_dec_mag(directory):
#      21     """
#      22     Organize FITS files in a directory by their RA, Dec, and Magnitude.
#      23     """
# ---> 24     fits_files = [file for file in os.listdir(directory) if file.endswith('.fits')]
# ...

# %%
from astropy.io import fits
import os

def get_ra_dec_mag(fits_file):
    """
    Extract RA, Dec, and magnitude from a FITS file header.
    """
    hdul = fits.open(fits_file)
    header = hdul[0].header
    
    # Extract RA, Dec, and Magnitude (assuming they are stored in the header)
    ra = header['RA']
    dec = header['DEC']
    mag = header['MAG']

    hdul.close()

    return ra, dec, mag

def organize_fits_by_ra_dec_mag(directory):
    """
    Organize FITS files in a directory by their RA, Dec, and Magnitude.
    """
    fits_files = [file for file in os.listdir(directory) if file.endswith('.fits')]

    grouped_files = {}

    for fits_file in fits_files:
        ra, dec, mag = get_ra_dec_mag(os.path.join(directory, fits_file))
        key = (ra, dec, mag)
        if key not in grouped_files:
            grouped_files[key] = []
        grouped_files[key].append(fits_file)

    return grouped_files

def main():
    directory = r'C:\Users\Jmell\Desktop\NGC 6819\Light\I_\combined\NGC6819_Light_I'-0001.fit'
    grouped_files = organize_fits_by_ra_dec_mag(directory)

    # Output organized files
    for key, files in grouped_files.items():
        ra, dec, mag = key
        output_directory = os.path.join(directory, f'RA{ra}_Dec{dec}_Mag{mag}')
        os.makedirs(output_directory, exist_ok=True)
        for fits_file in files:
            os.rename(os.path.join(directory, fits_file), os.path.join(output_directory, fits_file))

if __name__ == "__main__":
    main()
# Out:
#   Cell In[11], line 38
#     directory = r'C:\Users\Jmell\Desktop\NGC 6819\Light\I_\combined\NGC6819_Light_I'-0001.fit'
#                                                                                          ^
# SyntaxError: invalid decimal literal

# %%
from astropy.io import fits
import os

def get_ra_dec_mag(fits_file):
    """
    Extract RA, Dec, and magnitude from a FITS file header.
    """
    hdul = fits.open(fits_file)
    header = hdul[0].header
    
    # Extract RA, Dec, and Magnitude (assuming they are stored in the header)
    ra = header['RA']
    dec = header['DEC']
    mag = header['MAG']

    hdul.close()

    return ra, dec, mag

# Define the directory containing your FITS files
directory = r'C:\Users\Jmell\Desktop\NGC 6819\Light\I_\combined'

# Specify the FITS file you want to process
fits_file = os.path.join(directory, "NGC6819_Light_I_-0001.fit")

# Call the function to get RA, Dec, and Mag for the specified FITS file
ra, dec, mag = get_ra_dec_mag(fits_file)

# Output the results
print("RA:", ra)
print("Dec:", dec)
print("Magnitude:", mag)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 27
#      24 fits_file = os.path.join(directory, "NGC6819_Light_I_-0001.fit")
#      26 # Call the function to get RA, Dec, and Mag for the specified FITS file
# ---> 27 ra, dec, mag = get_ra_dec_mag(fits_file)
#      29 # Output the results
#      30 print("RA:", ra)
#
# Cell In[14], line 8, in get_ra_dec_mag(fits_file)
#       4 def get_ra_dec_mag(fits_file):
#       5     """
#       6     Extract RA, Dec, and magnitude from a FITS file header.
#       7     """
# ----> 8     hdul = fits.open(fits_file)
#       9     header = hdul[0].header
#      11     # Extract RA, Dec, and Magnitude (assuming they are stored in the header)
#
# ...
